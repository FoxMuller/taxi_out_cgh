# %% [markdown]
# ## Download of "Voos Regulares Ativos" VRA

# %% [markdown]
# ##### Download realizado manualmente do website: https://sistemas.anac.gov.br/dadosabertos/Voos%20e%20opera%C3%A7%C3%B5es%20a%C3%A9reas/Voo%20Regular%20Ativo%20%28VRA%29/
# ##### Dados coletados no formato csv e transferidos para a pasta <b>data/vra</b>
